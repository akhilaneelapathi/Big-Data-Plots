# %%
#Importing all necessary packages

from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D  
from matplotlib import cm 
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# %% [markdown]
# Part 2:
# 1) Make a pie chart that shows the distribution of animals in a zoo that contains 30 penguins, 40 polar bears, 20 lions, and 10 otters.

# %%
pie_df = pd.DataFrame({'animals': ['penguins', 'polar_bears', 'lions', 'others'],
                   'count': [30, 40, 20, 10]})
pie_df.set_index('animals', inplace=True)
#print(df)
plot = pie_df.plot.pie(y='count', subplots=True, shadow = True, startangle=270, figsize=(7, 7))

# %% [markdown]
# 2) Make a bar chart that shows the number of people, out of a total of 40, who like various movie types if 10 people like comedy; 8 people like action; 15 people like romance; 2 people like drama, and 5 people like sci-fi.

# %%
bar_df = pd.DataFrame({'movie_category':['comedy', 'action', 'romance', 'drama', 'sci-fi'], 'count':[10, 8, 15, 2, 5]})
#data = {"movie_category":["comedy", "action", "romance", "drama", "sci-fi"], "no_of_people":[10,8,15,2,5]};
     
#dataFrame = pd.DataFrame(data=data);

bar_df.plot(kind='bar',x="movie_category", y="count", rot=70, title="Number of people");
plt.show()

# %% [markdown]
# 3) Make both a side-by-side barplot and a stacked bar plot that displays the number of child visitors and the number of adult visitors at a waterpark in the months of April, May, June and July. Be sure to include titles, legends and appropriate labels sufficiently sized for readability.
#
# April
# Children: 780
# Adults: 315
#
# May
# Children: 1050
# Adults: 400
#
# June
# Children: 3056
# Adults: 1000
#
# July
# Children: 5025
# Adults: 1500

# %%
Children_sales = (780, 1050, 3056, 5025)
ind = np.arange(4)
width = 0.35
fig, ax = plt.subplots()

rects1 = ax.bar(ind, Children_sales, width, color='gray') 

#Second set of data-- creation of bars 
Adult_sales = (315, 400, 1000, 1500)
rects2 = ax.bar(ind + width, Adult_sales, width, color='brown')

# Add some text for labels, title and axes ticks
ax.set_ylabel('number of adult visitors',fontsize=13)
ax.set_title('number of child visitors',fontsize=13)
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('April', 'May', 'June', 'July'),fontsize=10)

#Create a legend 
ax.legend((rects1[0], rects2[0]), ('Children', 'Adults'))

plt.show()

# %%
child=(780,1050,3056,5025)
adult=(315,400,1000,1500)
months=('April','May','June','July')
x = np.arange(4)
plt.style.use("seaborn")
plt.bar(x, child)
plt.bar(x, adult)

plt.title('Number of child and Adult vistors at waterpark')
plt.legend(('children', 'Adult'))
plt.show()

# %% [markdown]
# 4. Histogram:
# Make a histogram of the following scores from the Fall 2017 Data Structures course. Feel free to experiment on the best number of histogram bins for visualization. 114.8, 98.8, 97.3, 96, 94.1, 93.1, 93.1, 91.6, 91.5, 91.3, 90.3, 89.2, 87.5, 87.4, 85.2, 81.7, 81.6, 81.5, 80, 79.3, 78.2, 77.6, 77.1, 76.7, 75.1, 73.9, 72, 71, 64.6, 63.3, 47.2, 38.7
# After this, save the image through code (no screenshots) into a vector graphics format (.svg, .pdf, .eps) and another version in a raster graphics format (.jpg, .png, .gif…). [Note: you will need to google how to save images through code into both formats. Hint: use plt.savefig() function in Python. You need to save the figure before running plt.show() function.]

# %%
x = [114.8, 98.8, 97.3, 96, 94.1, 93.1, 93.1, 91.6, 91.5, 91.3, 90.3, 89.2, 87.5, 87.4, 85.2, 81.7, 81.6, 81.5, 
     80, 79.3, 78.2, 77.6, 77.1, 76.7, 75.1, 73.9, 72, 71, 64.6, 63.3, 47.2, 38.7]
num_bins =5
n, bins, patches = plt.hist(x, num_bins, facecolor='gray', alpha=0.75, edgecolor='black')

plt.title('Histogram')
plt.xlabel('X-values',fontsize=14)
plt.ylabel('Y-values',fontsize=14)

plt.show()

# %% [markdown]
# Part 3:
# 1)Line Plot:
# Create a line plot of sin(x) and cos(x + π/2) for -2π < x < 2π where x increases at intervals of π/4.
# Make the sin(x) graph red and make the cos(x+π/2) graph green
# Put both lines onto the same plot
# Using the same info as above, make a subplot with 2 different graphs-
# one graph for sin(x) and
# one graph for cos(x+π/2)
# x = -6.283, -5.498, -4.712, -3.927, -3.142, -2.356, -1.571, -.7854, 0, .7854, 1.571, 2.356, 3.142, 3.927, 4.712, 5.498, 6.283
#
# sin(x) = 0, .70711, 1, .70711, 0, -.70711, -1, -.70711, 0, .70711, 1, .70711, 0, -.70711, -1, -.70711, 0
#
# cox(x + π/2) = 0, -.70711, -1, -.70711, 0, .70711, 1, .70711, 0, -.70711, -1, -.70711, 0, .70711, 1, .70711, 0

# %%
x = [-6.283, -5.498, -4.712, -3.927, -3.142, -2.356, -1.571, -.7854, 0, .7854, 1.571, 2.356, 3.142, 3.927, 4.712,
     5.498, 6.283]

sinx = [0, .70711, 1, .70711, 0, -.70711, -1, -.70711, 0, .70711, 1, .70711, 0, -.70711, -1, -.70711, 0]
cosx = [0, -.70711, -1, -.70711, 0, .70711, 1, .70711, 0, -.70711, -1, -.70711, 0, .70711, 1, .70711, 0]
# print(x, sinx, cosx)
# print(plt.style.available)
plt.style.use("ggplot")
plt.figure(num=1, figsize=(8,4))
plt.plot(x, sinx, label="sin(x)", linewidth="2.5", marker="o",linestyle="dashed", color="grey")
plt.plot(x, cosx, label="cos(x)", marker="^", color="red")
plt.yticks(np.arange(min(sinx), max(sinx), 0.25))
plt.legend(loc="upper left")
plt.title("Sin and Cosine wave functions")
plt.ylim([-1.1, 1.1])
plt.tight_layout()
plt.show()

# %% [markdown]
# 2) Using the following data about winter temperatures affecting the number of days for lake ice at Lake Superior, construct a scatter plot to display the data. Include a line of best fit.
#
# Mean Temperature (in Fahrenheit): 22.94, 23.02, 25.68, 19.96, 24.80, 23.98, 22.10, 20.30, 24.20, 22.74, 24.16, 24.94, 22.40, 22.14, 20.84, 25.66, 21.73, 24.49, 24.13, 22.17, 21.73, 20.41, 24.41, 23.95, 20.95, 26.71, 22.81, 23.11, 23.33, 28.83, 23.11, 21.47, 23.97, 24.75, 23.61, 23.08, 21.24, 26.63, 23.88
# Days of Ice: 87, 137, 106, 97, 105, 118, 118, 136, 91, 107, 96, 114, 125, 115, 118, 82, 115, 97, 104, 146, 126, 141, 111, 123, 118, 83, 48, 118, 116, 81, 116, 123, 112, 99, 102, 118, 63, 62, 132

# %%
#Getting x and y values
Mean_temperatures = [22.94, 23.02, 25.68, 19.96, 24.80, 23.98, 22.10, 20.30, 24.20, 22.74, 24.16, 24.94, 22.40, 22.14, 
                20.84, 25.66, 21.73, 24.49, 24.13, 22.17, 21.73, 20.41, 24.41, 23.95, 20.95, 26.71, 22.81, 23.11, 
                23.33, 28.83, 23.11, 21.47, 23.97, 24.75, 23.61, 23.08, 21.24, 26.63, 23.88]
Days_of_Ice = [87, 137, 106, 97, 105, 118, 118, 136, 91, 107, 96, 114, 125, 115, 118, 82, 115, 97, 104, 146, 126, 
             141, 111, 123, 118, 83, 48, 118, 116, 81, 116, 123, 112, 99, 102, 118, 63, 62, 132]


#Creating the scatter plot
plt.scatter(Mean_temperatures, Days_of_Ice, s=50, facecolors ='none', edgecolors='black', alpha=0.5)

#Labelling the plot
plt.xlabel('Average Temperature at the Pool (Degrees Fahrenheit)')
plt.ylabel('Number of Days with Ice')
plt.title('Number of Days with Ice vs. Average Temperature')
plt.plot(np.unique(Mean_temperatures),np.poly1d(np.polyfit(Mean_temperatures,Days_of_Ice,1))(np.unique(Mean_temperatures)))

#Outputting the scatter plot
plt.show()

# %% [markdown]
# Part 4:
# In your experiments you found that the phenomenon you are measuring is described by the following equation:
# Z = np.exp(-((X-1)**2+(Y-4)**2)/0.15) + \
#     np.exp(-((X-3)**2+(Y-4)**2)/0.15) + \
#     np.exp(-((X-2)**2+(Y-3)**2)/0.15) + \
#     np.exp(-(X-2)**2) * np.exp(-(Y - ((X-2)**2+1))**2/0.15)
# Note: For your convenience, the python version of the equation is written with np.exp referring to the exponentiation function ex from the numpy package name shortened to np (like in the tutorial). Also, ** is the power function. The ‘\’ is because python needs it for equations that continue over multiple lines - not necessary in other languages.
# Also, to be complete, be sure to show the contour plot for the entire range for which this function has interesting features to observe.

# %% [markdown]
# 1. Contour plot
# 1). Make a contour plot. Make sure to add labels in the plot or a legend for colors on the contours. You can choose either a filled contour plot or colored lines, your choice.
# 2). Do this for an additional color mapping: e.g. hot/cold or black/white.

# %%
#Defining the function 
def f(X,Y): 
 return np.exp(-((X-1)**2+(Y-4)**2)/0.15) + \
    np.exp(-((X-3)**2+(Y-4)**2)/0.15) + \
    np.exp(-((X-2)**2+(Y-3)**2)/0.15) + \
    np.exp(-(X-2)**2) * np.exp(-(Y - ((X-2)**2+1))**2/0.15)
 
#Building 2-dimensional grids from one-dimensional arrays 
x = np.linspace(0,5,50) 
y = np.linspace(0,6,60) 
X, Y = np.meshgrid(x, y) 
Z = f(X, Y) 
#Produce the color mapping with warm colors 
plt.contour(X, Y, Z, 15, cmap='RdGy'); 
contours = plt.contour(X, Y, Z, 3, colors='black') 
plt.clabel(contours, inline=True, fontsize=8) 
plt.title('Contour Plot')
plt.xlabel('X') 
plt.ylabel('Y') 
plt.imshow(Z, extent=[0, 5, 0, 6], origin='lower', 
 cmap='RdGy', alpha=0.5) 
plt.colorbar()

# %% [markdown]
# 2. Surface plots (or mesh plots)
# 1). Using the same data set as before, create a surface plot. Also be sure to choose an appropriate color mapping to help in interpretation. If you can’t make a surface plot, a mesh plot (where the surface is not filled in) will suffice.
# 2). Generate at least one additional viewpoint of the surface that may also be helpful in providing insights.

# %%
#an additional viewpoint 
fig = plt.figure(figsize=(8,6)) 
ax = fig.gca(projection='3d') #creating axes 
#Setting rotation angle of plot 
ax.view_init(elev=60,azim=30) 
# Make data. 
X = np.arange(0, 4, 0.25) #array of evenly spaced values 
Y = np.arange(0, 5, 0.25) #array of evenly spaced values 
X, Y = np.meshgrid(X, Y) 
Z = np.exp(-((X-1)**2+(Y-4)**2)/0.15) + \
    np.exp(-((X-3)**2+(Y-4)**2)/0.15) + \
    np.exp(-((X-2)**2+(Y-3)**2)/0.15) + \
    np.exp(-(X-2)**2) * np.exp(-(Y - ((X-2)**2+1))**2/0.15)

# Plot the surface. 
#The surface is made opaque by using antialiased=False. 
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,linewidth=0, antialiased=False) 
# Customize the z axis. 
ax.set_zlim(0, 1.0)
#Setting the tick locators-- choosing tick locations 
#Creates evenly spaced ticks from min to max  
ax.zaxis.set_major_locator(LinearLocator(5)) 
#sprintf format string 
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f')) 
# Add a color bar which maps values to colors. 
fig.colorbar(surf,shrink=0.6,aspect =10,pad=0.09) 
#Add labels for x,y, and z axes 
ax.set_xlabel('X axis',fontsize=10) 
ax.set_ylabel('Y axis',fontsize=10) 
ax.set_zlabel('Z axis',fontsize=10) 
ax.set_title('Cool-Warm Surface Plot',fontsize=10) 
plt.show()
